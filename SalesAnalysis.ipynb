# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
# Read the Excel file

data = pd.read_excel('Sample_Superstore(1) (Autosaved).xlsx')

# Display the first 5 rows

data.head(5)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   20847           High      0.01        2.84           0.93            3
# 1   20228  Not Specified      0.02      500.98          26.00            5
# 2   21776       Critical      0.06        9.48           7.29           11
# 3   24844         Medium      0.09       78.69          19.99           14
# 4   24846         Medium      0.08        3.28           2.31           14
#
#        Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0      Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 1     Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 2      Marcus Dunlap     Regular Air      Home Office        Furniture  ...
# 3  Gwendolyn F Tyson     Regular Air   Small Business        Furniture  ...
# 4  Gwendolyn F Tyson     Regular Air   Small Business  Office Supplies  ...
#
# ...

# %%
data.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Country', 'Region',
#        'State or Province', 'City', 'Postal Code', 'Order Date', 'Ship Date',
#        'Profit', 'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
data.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   1952.000000  1952.000000  1952.000000    1952.000000  1952.000000
# mean   19916.479508     0.048975   109.079221      12.968151  1735.376537
# min       64.000000     0.000000     1.140000       0.490000     3.000000
# 25%    19121.000000     0.020000     6.480000       3.230000   875.000000
# 50%    21164.500000     0.050000    20.990000       6.150000  1738.000000
# 75%    23483.250000     0.080000   100.972500      14.362500  2578.250000
# max    26389.000000     0.210000  6783.020000     164.730000  3403.000000
# std     5957.595627     0.031378   393.481301      17.414631   991.078006
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          1936.000000   1952.000000                           1952
# mean              0.515186  51534.769467  2015-03-29 01:21:08.852459008
# min               0.350000   1001.000000            2015-01-01 00:00:00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1952 entries, 0 to 1951
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                1952 non-null   int64
#  1   Order Priority        1952 non-null   object
#  2   Discount              1952 non-null   float64
#  3   Unit Price            1952 non-null   float64
#  4   Shipping Cost         1952 non-null   float64
#  5   Customer ID           1952 non-null   int64
#  6   Customer Name         1952 non-null   object
#  7   Ship Mode             1952 non-null   object
#  8   Customer Segment      1952 non-null   object
#  9   Product Category      1952 non-null   object
#  10  Product Sub-Category  1952 non-null   object
#  11  Product Container     1952 non-null   object
#  12  Product Name          1952 non-null   object
#  13  Product Base Margin   1936 non-null   float64
#  14  Country               1952 non-null   object
# ...

# %%
# Count the occurrences of each product container type
container_counts = data["Product Container"].value_counts()

# Display the result
print(container_counts)
# Out:
# Product Container
# Small Box     991
# Wrap Bag      279
# Small Pack    219
# Jumbo Drum    152
# Jumbo Box     124
# Large Box     100
# Medium Box     87
# Name: count, dtype: int64

# %%
# Get the value counts for 'Product Container'
container_counts = data["Product Container"].value_counts()

# Plotting a horizontal bar chart
plt.figure(figsize=(8, 6))
container_counts.plot(kind='barh', color='lightcoral')

# Adding title and labels
plt.title('Frequency of Product Containers')
plt.xlabel('Count')
plt.ylabel('Product Container')
plt.show()

# %%
# Grouping by 'Region' and summing up 'Shipping Cost'
region_shipping_cost = data.groupby('Region')["Shipping Cost"].sum().reset_index()

# Displaying the result
print(region_shipping_cost)
# Out:
#     Region  Shipping Cost
# 0  Central        7117.80
# 1     East        6541.00
# 2    South        5670.11
# 3     West        5984.92

# %%
# Create the barplot
plt.figure(figsize=(8, 6))
sns.barplot(x='Region', y='Shipping Cost', data=region_shipping_cost, color='teal')

# Adding labels and title
plt.title('Total Shipping Cost by Region', fontsize=14)
plt.xlabel('Region', fontsize=12)
plt.ylabel('Total Shipping Cost', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
ship_mode_summary = data.groupby('Ship Mode')[["Shipping Cost", "Profit"]].sum()

# %%
# Extracting data for plotting
ship_modes = ship_mode_summary.index
shipping_costs = ship_mode_summary['Shipping Cost']
profits = ship_mode_summary['Profit']

plt.figure(figsize=(10, 6))
plt.bar(x - width/2, shipping_costs, width, label='Shipping Cost', color='skyblue')
plt.bar(x + width/2, profits, width, label='Profit', color='lightgreen')

# Adding labels, title, and legend
plt.title('Shipping Cost and Profit by Ship Mode', fontsize=14)
plt.xlabel('Ship Mode', fontsize=12)
plt.ylabel('Amount', fontsize=12)
plt.xticks(x, ship_modes, rotation=45)
plt.tight_layout()
plt.show()

# %%
top10_cities_sales = data.groupby("State or Province")["Sales"].sum().nlargest(10)

# Displaying the result
print(top10_cities_sales)
# Out:
# State or Province
# California              288310.61
# New York                223930.48
# Illinois                 98971.25
# Texas                    93082.73
# Florida                  87651.11
# Washington               83468.06
# Michigan                 69641.81
# Ohio                     69452.82
# District of Columbia     68946.66
# Massachusetts            59114.82
# Name: Sales, dtype: float64

# %%
# Plotting the bar chart for top 10 states or provinces by sales
plt.figure(figsize=(10, 6))
top10_cities.plot(kind='bar', color='skyblue')

# Adding title and labels
plt.title('Top 10 States or Provinces by Total Sales')
plt.xlabel('State or Province', fontsize=12)
plt.ylabel('Total Sales', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
top10_cities_profit = data.groupby("State or Province")["Profit"].sum().nlargest(10)

# Displaying the result
print(top10_cities_profit)
# Out:
# State or Province
# California              37421.960192
# Texas                   28078.850660
# New York                27611.943319
# Ohio                    23410.842026
# Oregon                  17931.043400
# Illinois                12321.579312
# Michigan                12307.551892
# Georgia                 11838.491414
# District of Columbia    11677.363100
# Colorado                 6965.462660
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10, 6))
top10_cities_profit.plot(kind='bar', color='green')
# Adding title and labels
plt.title('Top 10 States or Provinces by Total Profit', fontsize=14)
plt.xlabel('State or Province', fontsize=12)
plt.ylabel('Total Profit', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %%
# Create a new column for Year-Month
data['Year-Month'] = data['Order Date'].dt.to_period('M')

# Group by 'Year-Month' and sum up the profits
monthly_profit = data.groupby('Year-Month')['Profit'].sum()

# Display the result
print(monthly_profit)
# Out:
# Year-Month
# 2015-01     1043.677500
# 2015-02    35944.658780
# 2015-03      103.159587
# 2015-04    53146.412502
# 2015-05    67002.732858
# 2015-06    66836.970610
# Freq: M, Name: Profit, dtype: float64

# %%
plt.figure(figsize=(12, 6))
Monthly_profit.plot(kind='line', marker='o', color='green')

# Adding title and labels
plt.title('Monthly Profit Trends', fontsize=14)
plt.xlabel('Year-Month')
plt.ylabel('Total Profit')
plt.grid(axis='y', linestyle='--')
plt.xticks(rotation=45)

plt.show()

# %%
# Create a new column for Year-Month
data['Year-Month'] = data['Order Date'].dt.to_period('M')

# Group by 'Year-Month' and sum up the sales
monthly_sales = data.groupby('Year-Month')['Sales'].sum()

# Display the result
print(monthly_sales)
# Out:
# Year-Month
# 2015-01    274766.92
# 2015-02    326101.47
# 2015-03    271696.67
# 2015-04    389831.95
# 2015-05    306572.07
# 2015-06    355368.80
# Freq: M, Name: Sales, dtype: float64

# %%
# Plotting the monthly sales trend
plt.figure(figsize=(12, 6))
monthly_sales.plot(kind='line', marker='^', color='blue')

# Adding title and labels
plt.title('Monthly Sales Trends')
plt.xlabel('Year-Month')
plt.ylabel('Total Sales')
plt.grid(axis='y', linestyle='--')
plt.xticks(rotation=45)
plt.show()
